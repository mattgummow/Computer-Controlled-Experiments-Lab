# %% [markdown]
# # Outline Python script for the Year 3 Physical Chemistry Lab Automated Data Acquisition
# ### Version 1.1 - Updated 10 October 2020
# Nick Brooks

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
blue_LED = pd.read_csv('Blue_LED.csv')
red_LED = pd.read_csv('Red_LED.csv')
yellow_LED = pd.read_csv('Yellow_LED.csv')
green_LED = pd.read_csv('Green_LED.csv')

# %%
#plot the graph before the optimisation
plt.plot(blue_LED['Read Voltage'], blue_LED['Read Current'],color='blue',label='Blue LED')
plt.plot(red_LED['Read Voltage'], red_LED['Read Current'],color='red',label='Red LED')
plt.plot(yellow_LED['Read Voltage'], yellow_LED['Read Current'],color='yellow',label='Yellow LED')
plt.plot(green_LED['Read Voltage'], green_LED['Read Current'],color='green',label='Green LED')
leg = plt.legend(loc = 'upper left')
plt.xlabel('Read Voltage(V)')
plt.ylabel('Read Current(mA)')
plt.title('Current against Voltage before the optimisation')


plt.savefig('Before optimisation3.png')

# %% [markdown]
# Plot out your data and think about how you could extend the experiment, for example, can you measure multiple LEDs and compare their response, how does the response of an LED compare to a standard resistor?

# %%
blue_LED = pd.read_csv('Blue_LED_50_0.3.csv')
red_LED = pd.read_csv('Red_LED_50_0.3.csv')
yellow_LED = pd.read_csv('Yellow_LED_50_0.3.csv')
green_LED = pd.read_csv('Green_LED_50_0.3.csv')
Resistor = pd.read_csv('Resistor_50_0.3.csv')

# %%
# plot the graph after the optimisation
plt.plot(blue_LED['Vol. across LED (V)'], blue_LED['Current (A)'],color='blue',label='Blue LED')
plt.plot(red_LED['Vol. across LED (V)'], red_LED['Current (A)'],color='red',label='Red LED')
plt.plot(yellow_LED['Vol. across LED (V)'], yellow_LED['Current (A)'],color='yellow',label='Yellow LED')
plt.plot(green_LED['Vol. across LED (V)'], green_LED['Current (A)'],color='green',label='Green LED')
plt.plot(Resistor['Vol. across LED (V)'], Resistor['Current (A)'],color='purple',label='Resistor')
leg = plt.legend(loc = 'upper left')
plt.xlabel('Vol. across LED (V)')
plt.ylabel('Current (mA)')
plt.title('Current against Voltage after the optimisation')
plt.savefig('After optimisation3.png')

# %%
# curve fitting of the resistor
x = Resistor['Vol. across LED (V)']
y = Resistor['Current (A)']

figure(figsize=[14,8])
fit=polyfit(x,y,1,cov=True)

params=fit[0]
params_cov=fit[1]

m=params[0]

c=params[1]

fitted=m*x+c
plt.plot(Resistor['Vol. across LED (V)'], Resistor['Current (A)'],color='blue',label='Resistor',linestyle='', marker = '.')
plt.plot(Resistor['Vol. across LED (V)'],fitted,color='orange',label='line of equation y = 10.01x +')
plt.xlabel('Read Voltage(V)')
plt.ylabel('Read Current(mA)')
plt.title('Current against voltage for resistor w/ linear regression to calculate gradient and resistance')

plt.savefig('resistor2.png')

# %%
# curve fitting of the Blue LED
def func(x, a, b, c):
     return a * np.exp(-b * x) + c
    
figure(figsize=[14,8])
x1 = blue_LED['Vol. across LED (V)']
y1 = blue_LED['Current (A)']
plt.plot(x1, y1, ".", label="Blue_LED",color = 'blue');

optimizedParameters, pcov = opt.curve_fit(func, x1, y1);
plt.plot(x1, func(x1, *optimizedParameters), label="fit", color='orange');

leg = plt.legend(loc = 'upper left')
plt.xlabel('Vol. across LED (V)')
plt.ylabel('Current (mA)')
plt.title('curve fitting of Blue LED')
plt.savefig('x1-2.png')

# %%
# curve fitting of all the LEDs and resistor
def func(x, a, b, c):
     return a * np.exp(-b * x) + c
    
figure(figsize=[14,8])
x4 = green_LED['Vol. across LED (V)']
y4 = green_LED['Current (A)']


optimizedParameters, pcov = opt.curve_fit(func, x4, y4);
plt.plot(x4, func(x4, *optimizedParameters), label="Green_LED", color='green');
x3 = yellow_LED['Vol. across LED (V)']
y3 = yellow_LED['Current (A)']


optimizedParameters, pcov = opt.curve_fit(func, x3, y3);
plt.plot(x3, func(x3, *optimizedParameters), label="Yellow_LED", color='yellow');

x2 = red_LED['Vol. across LED (V)']
y2 = red_LED['Current (A)']


optimizedParameters, pcov = opt.curve_fit(func, x2, y2);
plt.plot(x2, func(x2, *optimizedParameters), label="Red_LED", color='red');

x1 = blue_LED['Vol. across LED (V)']
y1 = blue_LED['Current (A)']


optimizedParameters, pcov = opt.curve_fit(func, x1, y1);
plt.plot(x1, func(x1, *optimizedParameters), label="Blue_LED", color='blue');


plt.plot(Resistor['Vol. across LED (V)'],fitted,label="Resistor",color='purple')

leg = plt.legend(loc = 'upper left')
plt.xlabel('Vol. across LED (V)')
plt.ylabel('Current (mA)')
plt.title('Curve Fitting')
plt.savefig('Curve Fitting2.png')

# %%
blue_LED_2_0_1 = pd.read_csv('Blue_LED_2V_01.csv')
blue_LED_2_0_2 = pd.read_csv('Blue_LED_2V_02.csv')
blue_LED_2_0_3 = pd.read_csv('Blue_LED_2V_03.csv')
blue_LED_2_0_4 = pd.read_csv('Blue_LED_2V_04.csv')
blue_LED_2_0_5 = pd.read_csv('Blue_LED_2V_05.csv')
blue_LED_2_0_6 = pd.read_csv('Blue_LED_2V_06.csv')
blue_LED_2_0_7 = pd.read_csv('Blue_LED_2V_07.csv')
blue_LED_2_0_8 = pd.read_csv('Blue_LED_2V_08.csv')
blue_LED_2_0_9 = pd.read_csv('Blue_LED_2V_09.csv')
blue_LED_2_1_0 = pd.read_csv('Blue_LED_2V_10.csv')

# %%
std1=blue_LED_2_0_1['Vol. across LED (V)'].std()
std2=blue_LED_2_0_2['Vol. across LED (V)'].std()
std3=blue_LED_2_0_3['Vol. across LED (V)'].std()
std4=blue_LED_2_0_4['Vol. across LED (V)'].std()
std5=blue_LED_2_0_5['Vol. across LED (V)'].std()
std6=blue_LED_2_0_6['Vol. across LED (V)'].std()
std7=blue_LED_2_0_7['Vol. across LED (V)'].std()
std8=blue_LED_2_0_8['Vol. across LED (V)'].std()
std9=blue_LED_2_0_9['Vol. across LED (V)'].std()
std10=blue_LED_2_1_0['CVol. across LED (V)'].std()

# %%
std_V_list=[std1,std2,std3,std4,std5,std6,std7,std8,std9,std10]
delay_list= np.arange(0.1,1.1,0.1).round(2)

df_2V = pd.DataFrame(data = zip(std_V_list, delay_list), columns = ['Std','time delay'])
df_2V
# Out:
#         Std  time delay
# 0  0.026067         0.1
# 1  0.016187         0.2
# 2  0.020085         0.3
# 3  0.019002         0.4
# 4  0.016524         0.5
# 5  0.019435         0.6
# 6  0.019313         0.7
# 7  0.020684         0.8
# 8  0.014075         0.9
# 9  0.016765         1.0

# %%
plt.plot(df_2V['time delay'], df_2V['Std'],marker='^')
plt.xlabel('time delay')
plt.ylabel('Standard deviation')
plt.title('Std for the Voltage across LED')
plt.savefig('std for voltage_time delay.png')

# %%
std1A=blue_LED_2_0_1['Current (A)'].std()
std2A=blue_LED_2_0_2['Current (A)'].std()
std3A=blue_LED_2_0_3['Current (A)'].std()
std4A=blue_LED_2_0_4['Current (A)'].std()
std5A=blue_LED_2_0_5['Current (A)'].std()
std6A=blue_LED_2_0_6['Current (A)'].std()
std7A=blue_LED_2_0_7['Current (A)'].std()
std8A=blue_LED_2_0_8['Current (A)'].std()
std9A=blue_LED_2_0_9['Current (A)'].std()
std10A=blue_LED_2_1_0['Current (A)'].std()

# %%
std_A_list=[std1A,std2A,std3A,std4A,std5A,std6A,std7A,std8A,std9A,std10A]

df_2A = pd.DataFrame(data = zip(std_A_list, delay_list), columns = ['Std','time delay'])
df_2A
# Out:
#         Std  time delay
# 0  0.000688         0.1
# 1  0.000665         0.2
# 2  0.000556         0.3
# 3  0.000651         0.4
# 4  0.000575         0.5
# 5  0.000588         0.6
# 6  0.000618         0.7
# 7  0.000633         0.8
# 8  0.000754         0.9
# 9  0.000701         1.0

# %%
plt.plot(df_2A['time delay'], df_2A['Std'],marker='^')
plt.xlabel('time delay')
plt.ylabel('Standard deviation')
plt.title('Std for Current')
plt.savefig('std for current_time delay.png')

# %%
blue_LED_3_03_10 = pd.read_csv('Blue_LED_3V_03_10_repeats.csv')
blue_LED_3_03_20=pd.read_csv('Blue_LED_3V_03_20_repeats.csv')
blue_LED_3_03_30= pd.read_csv('Blue_LED_3V_03_30_repeats.csv')
blue_LED_3_03_40= pd.read_csv('Blue_LED_3V_03_40_repeats.csv')
blue_LED_3_03_50=pd.read_csv('Blue_LED_3V_03_50_repeats.csv')
blue_LED_3_03_60=pd.read_csv('Blue_LED_3V_03_60_repeats.csv')
blue_LED_3_03_70=pd.read_csv('Blue_LED_3V_03_70_repeats.csv')
blue_LED_3_03_80 = pd.read_csv('Blue_LED_3V_03_80_repeats.csv')
blue_LED_3_03_90=pd.read_csv('Blue_LED_3V_03_90_repeats.csv')
blue_LED_3_03_100= pd.read_csv('Blue_LED_3V_03_100_repeats.csv')

# %%
std1=blue_LED_3_03_10['Vol. across LED (V)'].std()
std2=blue_LED_3_03_20['Vol. across LED (V)'].std()
std3=blue_LED_3_03_30['Vol. across LED (V)'].std()
std4=blue_LED_3_03_40['Vol. across LED (V)'].std()
std5=blue_LED_3_03_50['Vol. across LED (V)'].std()
std6=blue_LED_3_03_60['Vol. across LED (V)'].std()
std7=blue_LED_3_03_70['Vol. across LED (V)'].std()
std8=blue_LED_3_03_80['Vol. across LED (V)'].std()
std9=blue_LED_3_03_90['Vol. across LED (V)'].std()
std10=blue_LED_3_03_100['Vol. across LED (V)'].std()

# %%
std_V_list=[std1,std2,std3,std4,std5,std6,std7,std8,std9,std10]
repeat_list= np.arange(10,110,10)

df_3V = pd.DataFrame(data = zip(std_V_list, repeat_list), columns = ['Std','repeats'])
df_3V
# Out:
#         Std  repeats
# 0  0.004074       10
# 1  0.003470       20
# 2  0.003538       30
# 3  0.003400       40
# 4  0.003283       50
# 5  0.003369       60
# 6  0.004018       70
# 7  0.003321       80
# 8  0.003897       90
# 9  0.003548      100

# %%
plt.plot(df_3V['repeats'], df_3V['Std'],marker='^')
plt.xlabel('repeats')
plt.ylabel('Standard deviation')
plt.title('Std of Voltage')
plt.savefig('std for voltage_repeat.png')

# %%
std1A=blue_LED_3_03_10['Current (A)'].std()
std2A=blue_LED_3_03_20['Current (A)'].std()
std3A=blue_LED_3_03_30['Current (A)'].std()
std4A=blue_LED_3_03_40['Current (A)'].std()
std5A=blue_LED_3_03_50['Current (A)'].std()
std6A=blue_LED_3_03_60['Current (A)'].std()
std7A=blue_LED_3_03_70['Current (A)'].std()
std8A=blue_LED_3_03_80['Current (A)'].std()
std9A=blue_LED_3_03_90['Current (A)'].std()
std10A=blue_LED_3_03_100['Current (A)'].std()

# %%
std_A_list=[std1A,std2A,std3A,std4A,std5A,std6A,std7A,std8A,std9A,std10A]

df_3A = pd.DataFrame(data = zip(std_A_list, repeat_list), columns = ['Std','repeats'])
df_3A
# Out:
#         Std  repeats
# 0  0.018870       10
# 1  0.014540       20
# 2  0.011407       30
# 3  0.010690       40
# 4  0.009854       50
# 5  0.008165       60
# 6  0.007085       70
# 7  0.008113       80
# 8  0.006271       90
# 9  0.006070      100

# %%
plt.plot(df_3A['repeats'], df_3A['Std'],marker='^')
plt.xlabel('repeats')
plt.ylabel('Standard deviation')
plt.title('Std of Current')
plt.savefig('std for current_repeat.png')
